# %%
import pandas as pd
import os
import matplotlib.pyplot as plt

# %%
directory = 'data/'
questionnairs = dict()

for file in os.listdir(directory):
    filename = os.fsdecode(file)
    if filename.endswith('csv'):
        questionnairs[filename] = {}
        with open(directory + filename) as f:
            lines = f.readlines()
            for line in lines:
                ans = "".join(line.split(',')[1:]).strip("\n")
                try:
                    questionnairs[filename][line.split(',')[0]] = int(ans)
                except:
                    questionnairs[filename][line.split(',')[0]] = ans

# %%
isinstance(questionnairs['response_wanhao_1.csv']['1.1'], int)
# Out:
# True

# %%
anws = dict()
for _, questionnair in questionnairs.items():
    for question in questionnair.keys():
        if question not in anws.keys():
            anws[question] = []
        anw = questionnair[question]
        if isinstance(anw, int):
            anws[question].append(anw)

# %%
anws_text = dict()
for _, questionnair in questionnairs.items():
    for question in questionnair.keys():
        if question not in anws_text.keys():
            anws_text[question] = []
        anw = questionnair[question]
        if not isinstance(anw, int):
            anws_text[question].append(anw)

# %%
anws_text
# Out:
# {'1.1': [],
#  '1.2': [],
#  '1.3': [],
#  '1.4': ["the textual description could have more details the text doesn't always seem to fit with the formulas above",
#   'leenard jones equation and derivation to obtain useful formulae',
#   'The development between at its max and min',
#   'EMPTY',
#   'the potential varies with the radius in a complex way probably increasing sharply at very small radius and then decreasing to a minima which I know corresponds to an equilibrium position',
#   'The development between at its max and min',
#   'i think the part about finding the two equations to determine the two constants is a bit confusing (I did not understand that we were using the distance at which the potential is minimum)',
#   'We understand the force acting on theparticle and the energy related to their interaction',
#   'I only understood the first few equations more text would be useful to explain what is done',
#   'Not much that there is a mathematical relation between the force and the potential',
#   'missing data for the force (how can you relate it from an example)',
#   'their unity'],
#  '1.5': ["yes I couldn't always understand how it was relevant with the formulas that were above it",
#   'no i think they are important to provide context and better understand the process',
#   'not really it helps understanding',
#   'EMPTY',
#   'Very little text probably not enough to understand without some prior knowledge',
#   "no I'd rather have some more details also in text form",
#   'it is rather helpful but I think it could be made clearer.',
#   'it is more distracting than the plots. Maybe add some more description on what are the given equation. Adding some comments on each equation to remind what it is',
#   'No',
#   'No the text helps to understand better the equations but not enough to be able to understand the concept behind them.',
#   'yes',
#   'no'],
#  '1.6': ['I am not sure I could be able to describe the nature of the function based on the information. I think I am being biased from already knowing the answer',
#   'equation with one minima but a plot would be clearer',
#   'that there is a repulsive and an attractive part and it describes the energy',
#   'EMPTY',
#   'The function allows us to find attractive and or repulsive forces between particles depending on their respective distance',
#   'that there is a repulsive and an attractive part and it describes the energy',
#   'convex for low distances but concave for high distances',
#   'first the potential is concave and at higher distance it becomes convex',
#   'EMPTY',
#   'as you increase the distance the force decreases',
#   "it's increasing up to rmin then it's decreasing",
#   'potentiel'],
#  '2.1': [],
#  '2.2': [],
#  '2.3': [],
#  '2.4': [],
#  '2.5': [],
#  '2.6': [],
#  '2.7': ['you can really see that the LJ potential can be approximated to a parabolic shape',
#   'yes visualize difference in slope between small and large r',
#   'there is a miniumum in the graph and it grows exponentially',
#   'EMPTY',
#   'I knew the plot already and had it in mind when filling questions 1.1 to 1.3. Seeing the plot is very useful',
#   'there is a miniumum in the graph and it grows exponentially',
#   'function is tending to infinity for low r the goodness of the approximation of the parabolic potential',
#   'the forces reaches a maximum at a given distance and the approximation of the potential matches only to a certain degree the reality',
#   "It's easier to understand their meaning and the influence they have on atomic positions than just having the equation written",
#   'when the distance is below a certain value the absolute value of the force increases radically',
#   'it behaves like a spring (kind of example that was missing from the text)',
#   'no'],
#  '2.8': ['you can see the approximation of the LJ potential to a parabolic curve for certain values of r but how it deviates when r changes',
#   'understand physical explanations linked to the potential',
#   'geometric interactions f.ex. the force of LJ "is reflected" on the y axis ',
#   'EMPTY',
#   'red and blue curve are less obvious but the evolution of force and potential with the distance is clearer',
#   'geometric interactions f.ex. the force of LJ "is reflected" on the y axis ',
#   'it is useful to understand the link between force and potential',
#   'the relation between the approximation and the reality the relation between the force and energy',
#   'EMPTY',
#   'The steps of approximations used in order to get the final force plot',
#   'the repulsive and attractive part are well shown',
#   'how does LJ function looks like'],
#  '2.9': ["I feel that the text on the static plot is distracting I however don't mind static plots in general. One could argue about the values of the parameters chosen for this plot without explanation",
#   'no',
#   'not at all contrary it helps',
#   'EMPTY',
#   'Maybe too many curves',
#   'not at all contrary it helps',
#   'understanding',
#   'no',
#   'no',
#   'No the only missing thing is visualising the physical concept',
#   'yes',
#   'no'],
#  '2.10': ["LJ potential behaves as a parabolic function for values of r close to r0 and deviates when r changes. The effect of the parameter epsilon is not clear on this plot I can't tell how the function would evolve when changing the value of epsilon",
#   'yes difference btw force and potential',
#   'yes  i can better match an image to how the curves behave in a 2dimensional space',
#   'EMPTY',
#   "Don't understand the question. It's a potential variation with the distance with a force minima around 1.1",
#   'yes  i can better match an image to how the curves behave in a 2dimensional space',
#   'convex for low r and concave for high r tending to 0 at infinity',
#   'yes it is way easier to get the shape of the function',
#   'EMPTY',
#   'The equilibrium where the force is zero is easily found here at r=1.0',
#   'behaves like a spring',
#   '...'],
#  '3.1': [],
#  '3.2': [],
#  '3.3': [],
#  '3.4': [],
#  '3.5': [],
#  '3.6': [],
#  '3.7': [],
#  '3.8': [],
#  '3.9': [],
#  '3.10': [],
#  '3.11': ['how parameters change the nature of the functions',
#   'good to answer questions',
#   'how fast they increase and decrease and how actually one influences the other parameter',
#   'EMPTY',
#   '-',
#   'how fast they increase and decrease and how actually one influences the other parameter',
#   'the dependency on r0',
#   'maybe add the value of the maxima of the force',
#   'EMPTY',
#   'as eps0 increases the equilibrium is more stable',
#   'the potential how does the real model match with the simplified one',
#   'not really'],
#  '3.12': ["i would move the labels showing the value of epsilon r0 and E and put them on the side so it doesn't overlap with the curves",
#   'distracting potentially',
#   'the response time is a bit low and difference between yellow and blue is not clearly defined',
#   'EMPTY',
#   'I would appreciate to be able to move a cursor on the curves and see the values',
#   'the response time is a bit low and difference between yellow and blue is not clearly defined',
#   'the axis for E=0 is missing',
#   'I think we understand less the variation of the curve when we vary r0 than when we vary eps0',
#   'EMPTY',
#   "The y=0 line isn't represented hence hard to see where the equilibrium is.",
#   'missing the line which splits attractive\\repuslive part',
#   'lagging'],
#  '3.13': ['changing the slider position to vary eps0',
#   'EMPTY',
#   'how the 2 differ depending on each other',
#   'EMPTY',
#   "eps0 because I didn't understand the relationship",
#   'how the 2 differ depending on each other',
#   'varying r0 beacause I did not expect it to change the potential function like this',
#   'eps0',
#   'EMPTY',
#   "the r0 as it's dimension is more familiar I know exactly what it represents",
#   'e0 to match with the taylor approximation ',
#   'both'],
#  '3.14': ['not necessarilzx interactions but I would remind the relationship between the different curves that are plotted',
#   'EMPTY',
#   'maybe connect them to real life examples',
#   'EMPTY',
#   'A cursor that moves with position in r',
#   'maybe connect them to real life examples',
#   'zooming in or out on the plot',
#   'EMPTY',
#   'EMPTY',
#   'an interaction with two atoms where you can approach them to each other and change r and have a cursor that follows the lgraphs',
#   'make this split line',
#   'more legends']}

# %%
questions_text = {'1.4': 'What did you understand from the given textual description and equation?',
'1.5': 'Did you feel textual descriptions distracting in understanding?',
'1.6': 'From the information given above, what can you comment on the nature of function?',
'2.7': 'After seeing the static plot, can you comment something new on the nature of the function?',
'2.8': 'What did you understand from the given static plot?',
'2.9': 'Did you feel static plot distracting in understanding?',
'2.10': 'From the information given above, can you comment on the nature of function?' ,
'3.11':'Can you comment something about new which the interactive plot made you understand / realize ?',
'3.12':'What did you dislike about the interactive plot?',
'3.13': 'What interactions did you use the most and why ?',
'3.14': 'What other interactions could have helped you better?'}

# %%
qa = {}
for _id, _question in questions_text.items():
    qa[_question] = anws_text[_id]

# %%
qa
# Out:
# {'What did you understand from the given textual description and equation?': ["the textual description could have more details the text doesn't always seem to fit with the formulas above",
#   'leenard jones equation and derivation to obtain useful formulae',
#   'The development between at its max and min',
#   'EMPTY',
#   'the potential varies with the radius in a complex way probably increasing sharply at very small radius and then decreasing to a minima which I know corresponds to an equilibrium position',
#   'The development between at its max and min',
#   'i think the part about finding the two equations to determine the two constants is a bit confusing (I did not understand that we were using the distance at which the potential is minimum)',
#   'We understand the force acting on theparticle and the energy related to their interaction',
#   'I only understood the first few equations more text would be useful to explain what is done',
#   'Not much that there is a mathematical relation between the force and the potential',
#   'missing data for the force (how can you relate it from an example)',
#   'their unity'],
#  'Did you feel textual descriptions distracting in understanding?': ["yes I couldn't always understand how it was relevant with the formulas that were above it",
#   'no i think they are important to provide context and better understand the process',
#   'not really it helps understanding',
#   'EMPTY',
#   'Very little text probably not enough to understand without some prior knowledge',
#   "no I'd rather have some more details also in text form",
#   'it is rather helpful but I think it could be made clearer.',
#   'it is more distracting than the plots. Maybe add some more description on what are the given equation. Adding some comments on each equation to remind what it is',
#   'No',
#   'No the text helps to understand better the equations but not enough to be able to understand the concept behind them.',
#   'yes',
#   'no'],
#  'From the information given above, what can you comment on the nature of function?': ['I am not sure I could be able to describe the nature of the function based on the information. I think I am being biased from already knowing the answer',
#   'equation with one minima but a plot would be clearer',
#   'that there is a repulsive and an attractive part and it describes the energy',
#   'EMPTY',
#   'The function allows us to find attractive and or repulsive forces between particles depending on their respective distance',
#   'that there is a repulsive and an attractive part and it describes the energy',
#   'convex for low distances but concave for high distances',
#   'first the potential is concave and at higher distance it becomes convex',
#   'EMPTY',
#   'as you increase the distance the force decreases',
#   "it's increasing up to rmin then it's decreasing",
#   'potentiel'],
#  'After seeing the static plot, can you comment something new on the nature of the function?': ['you can really see that the LJ potential can be approximated to a parabolic shape',
#   'yes visualize difference in slope between small and large r',
#   'there is a miniumum in the graph and it grows exponentially',
#   'EMPTY',
#   'I knew the plot already and had it in mind when filling questions 1.1 to 1.3. Seeing the plot is very useful',
#   'there is a miniumum in the graph and it grows exponentially',
#   'function is tending to infinity for low r the goodness of the approximation of the parabolic potential',
#   'the forces reaches a maximum at a given distance and the approximation of the potential matches only to a certain degree the reality',
#   "It's easier to understand their meaning and the influence they have on atomic positions than just having the equation written",
#   'when the distance is below a certain value the absolute value of the force increases radically',
#   'it behaves like a spring (kind of example that was missing from the text)',
#   'no'],
#  'What did you understand from the given static plot?': ['you can see the approximation of the LJ potential to a parabolic curve for certain values of r but how it deviates when r changes',
#   'understand physical explanations linked to the potential',
#   'geometric interactions f.ex. the force of LJ "is reflected" on the y axis ',
#   'EMPTY',
#   'red and blue curve are less obvious but the evolution of force and potential with the distance is clearer',
#   'geometric interactions f.ex. the force of LJ "is reflected" on the y axis ',
#   'it is useful to understand the link between force and potential',
#   'the relation between the approximation and the reality the relation between the force and energy',
#   'EMPTY',
#   'The steps of approximations used in order to get the final force plot',
#   'the repulsive and attractive part are well shown',
#   'how does LJ function looks like'],
#  'Did you feel static plot distracting in understanding?': ["I feel that the text on the static plot is distracting I however don't mind static plots in general. One could argue about the values of the parameters chosen for this plot without explanation",
#   'no',
#   'not at all contrary it helps',
#   'EMPTY',
#   'Maybe too many curves',
#   'not at all contrary it helps',
#   'understanding',
#   'no',
#   'no',
#   'No the only missing thing is visualising the physical concept',
#   'yes',
#   'no'],
#  'From the information given above, can you comment on the nature of function?': ["LJ potential behaves as a parabolic function for values of r close to r0 and deviates when r changes. The effect of the parameter epsilon is not clear on this plot I can't tell how the function would evolve when changing the value of epsilon",
#   'yes difference btw force and potential',
#   'yes  i can better match an image to how the curves behave in a 2dimensional space',
#   'EMPTY',
#   "Don't understand the question. It's a potential variation with the distance with a force minima around 1.1",
#   'yes  i can better match an image to how the curves behave in a 2dimensional space',
#   'convex for low r and concave for high r tending to 0 at infinity',
#   'yes it is way easier to get the shape of the function',
#   'EMPTY',
#   'The equilibrium where the force is zero is easily found here at r=1.0',
#   'behaves like a spring',
#   '...'],
#  'Can you comment something about new which the interactive plot made you understand / realize ?': ['how parameters change the nature of the functions',
#   'good to answer questions',
#   'how fast they increase and decrease and how actually one influences the other parameter',
#   'EMPTY',
#   '-',
#   'how fast they increase and decrease and how actually one influences the other parameter',
#   'the dependency on r0',
#   'maybe add the value of the maxima of the force',
#   'EMPTY',
#   'as eps0 increases the equilibrium is more stable',
#   'the potential how does the real model match with the simplified one',
#   'not really'],
#  'What did you dislike about the interactive plot?': ["i would move the labels showing the value of epsilon r0 and E and put them on the side so it doesn't overlap with the curves",
#   'distracting potentially',
#   'the response time is a bit low and difference between yellow and blue is not clearly defined',
#   'EMPTY',
#   'I would appreciate to be able to move a cursor on the curves and see the values',
#   'the response time is a bit low and difference between yellow and blue is not clearly defined',
#   'the axis for E=0 is missing',
#   'I think we understand less the variation of the curve when we vary r0 than when we vary eps0',
#   'EMPTY',
#   "The y=0 line isn't represented hence hard to see where the equilibrium is.",
#   'missing the line which splits attractive\\repuslive part',
#   'lagging'],
#  'What interactions did you use the most and why ?': ['changing the slider position to vary eps0',
#   'EMPTY',
#   'how the 2 differ depending on each other',
#   'EMPTY',
#   "eps0 because I didn't understand the relationship",
#   'how the 2 differ depending on each other',
#   'varying r0 beacause I did not expect it to change the potential function like this',
#   'eps0',
#   'EMPTY',
#   "the r0 as it's dimension is more familiar I know exactly what it represents",
#   'e0 to match with the taylor approximation ',
#   'both'],
#  'What other interactions could have helped you better?': ['not necessarilzx interactions but I would remind the relationship between the different curves that are plotted',
#   'EMPTY',
#   'maybe connect them to real life examples',
#   'EMPTY',
#   'A cursor that moves with position in r',
#   'maybe connect them to real life examples',
#   'zooming in or out on the plot',
#   'EMPTY',
#   'EMPTY',
#   'an interaction with two atoms where you can approach them to each other and change r and have a cursor that follows the lgraphs',
#   'make this split line',
#   'more legends']}

# %%
title_hist = {'1.1': 'How well do the textual description and the corresponding equation help you fully understand the concepts?',
    '1.2': 'How well does the equation help you understand how the function changes in value when parameters change?',
'1.3': 'How well can you understand the relationship between the force and potential with varying parameter?',
'2.1': 'How well does the static plot help you fully understand the concepts?',
'2.2': 'How well does the static plot help you understand how the function changes in value when parameters change?',
'2.3': 'After seeing the plot, how well can you understand the relation between force/potential and varying parameter?',
'2.4': 'To which degree does the image matches with your understanding of 1.1, 1.2 and 1.3',
'2.5': 'To which degree does the image helps you understand 1.1, 1.2 and 1.3 better?',
'2.6': 'To which degree is the image helpful for your understanding ?',
'3.1':'How well does the interactive plot help you fully understand the concepts?',
'3.2':'How well does the interactive plot help you understand how function changes in value when parameters change?',
'3.3':'How well does the  interactive plot help you understand the relationship between the force with varying parameters?',
'3.4':'The interactive plot matches with your prior understanding of the concepts ',
'3.5':'The interactive plot matches with your prior understanding of how the Force, Potential functions would look like ?',
'3.6':'The interactive plot matches with your prior understanding of how the Force, Potential functions vary with r0 , eps0 ?',
'3.7':'The interactive plot helps you BETTER UNDERSTAND the concepts compared to just STATIC PLOT?',
'3.8':'The interactive plot helps you BETTER UNDERSTAND how the Force, Potential functions would look like ?',
'3.9': 'The interactive plot helps you BETTER UNDERSTANDhow the Force, Potential functions  would vary with r0 , eps0 ?',
'3.10': 'To what degree is the interactive plot helful to you for understanding the concepts ?',
}

# %%
anws.items()
# Out:
# dict_items([('1.1', [2, 8, 6, 3, 2, 5, 5, 8, 4, 4, 5, 7]), ('1.2', [3, 3, 6, 4, 2, 6, 7, 7, 4, 2, 8, 9]), ('1.3', [2, 8, 4, 1, 2, 5, 10, 8, 4, 1, 10, 1]), ('1.4', []), ('1.5', []), ('1.6', []), ('2.1', [5, 8, 8, 6, 5, 9, 10, 10, 5, 8, 10, 6]), ('2.2', [2, 10, 7, 7, 7, 1, 9, 8, 4, 9, 5, 7]), ('2.3', [2, 8, 3, 7, 7, 3, 10, 10, 5, 8, 10, 8]), ('2.4', [2, 9, 4, 1, 7, 4, 10, 7, 6, 9, 8, 1]), ('2.5', [4, 10, 3, 6, 6, 3, 7, 10, 5, 8, 3, -5]), ('2.6', [4, 10, 9, 7, 4, 9, 7, 10, 7, 10, 7, 3]), ('2.7', []), ('2.8', []), ('2.9', []), ('2.10', []), ('3.1', [7, 7, 10, 9, 8, 10, 8, 7, 7, 8, 10, 1]), ('3.2', [7, 10, 10, 9, 7, 10, 9, 10, 9, 10, 10, 5]), ('3.3', [7, 7, 8, 8, 8, 8, 8, 9, 8, 10, 10, 4]), ('3.4', [5, 10, 4, 1, 9, 4, 10, 9, 7, 10, 10, 2]), ('3.5', [5, 10, 3, 1, 10, 3, 9, 9, 8, 10, 10, 5]), ('3.6', [5, 10, 6, 1, 6, 6, 7, 9, 8, 8, 10, 6]), ('3.7', [8, 7, 8, 8, 6, 8, 6, 10, 10, 9, 8, 8]), ('3.8', [8, 1, 9, 9, 6, 9, 5, 10, 10, 7, 8, 5]), ('3.9', [8, 10, 9, 8, 7, 9, 9, 10, 10, 10, 10, 5]), ('3.10', [8, 7, 10, 7, 6, 10, 7, 10, 8, 9, 9, 5]), ('3.11', []), ('3.12', []), ('3.13', []), ('3.14', [])])

# %%
for name, question in anws.items():
    if question: 
        
        figure = plt.figure(figsize=(8, 8))
        try:
            plt.title(name + "  "+ title_hist[name])
            #print(title_hist[name])
        except:
            pass
        #ax = figure.add_subplot(111)
        plt.hist(question)
        plt.show()
